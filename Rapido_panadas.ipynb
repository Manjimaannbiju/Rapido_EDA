# %%
#!unzip '/content/drive/MyDrive/ML_LUMINAR/archive (23).zip'

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/rides_data.csv')

# %% [markdown]
# UNDERSTANDING DATA

# %%
df.shape
# Out:
# (50000, 13)

# %%
df.dtypes
# Out:
# services           object
# date               object
# time               object
# ride_status        object
# source             object
# destination        object
# duration            int64
# ride_id            object
# distance          float64
# ride_charge       float64
# misc_charge       float64
# total_fare        float64
# payment_method     object
# dtype: object

# %%
df
# Out:
#           services        date             time ride_status  \
# 0      cab economy  2024-07-15  08:30:40.542646   completed
# 1             auto  2024-07-05  23:36:51.542646   completed
# 2             auto  2024-07-23  11:05:37.542646   cancelled
# 3      cab economy  2024-06-24  08:45:10.542646   completed
# 4      cab economy  2024-07-15  00:26:44.542646   completed
# ...            ...         ...              ...         ...
# 49995  cab economy  2024-07-24  10:12:37.811393   completed
# 49996         auto  2024-08-12  11:24:08.811393   completed
# 49997         bike  2024-08-10  21:52:48.811393   completed
# 49998         auto  2024-07-07  20:44:00.811393   completed
# 49999  cab economy  2024-08-07  08:53:25.811393   completed
#
#                        source               destination  duration  \
# 0             Balagere Harbor           Harohalli Nagar        39
# 1      Basavanagudi 3rd Block      Bikasipura 1st Stage        89
# 2            Babusapalya Cove         Kothaguda Terrace        25
# 3           Mahadevapura Mews            Kanakapura Arc        89
# 4             Ganganagar Cove  Basaveshwaranagar Colony        95
# ...                       ...                       ...       ...
# 49995     Giri Nagar Quarters    Lingarajapuram Village        79
# 49996    Hennur Road District             Hulimavu Pier        39
# 49997           Agara Heights          Ulsoor 4th Block        40
# 49998            Hosur Colony          Kanakapura Works       111
# 49999     BTM 2nd Stage Depot          Thanisandra Pass        28
#
#                   ride_id  distance  ride_charge  misc_charge  total_fare  \
# 0      RD3161218751875354     27.21       764.83        31.51      796.34
# 1      RD8171514284594096     34.03       314.83        49.52      364.35
# 2      RD9376481122237926     20.24          NaN          NaN         NaN
# 3      RD3676889143182765     31.17       484.73        15.84      500.57
# 4      RD6639410275948084     27.21       663.50        14.13      677.63
# ...                   ...       ...          ...          ...         ...
# 49995  RD1742789687725650      7.03       518.90        23.81      542.71
# 49996  RD3524793949448023     31.77       977.34         2.67      980.01
# 49997  RD6755775741450371     25.74       331.94        38.32      370.26
# 49998  RD9198658614373790     11.70       565.47         0.33      565.80
# 49999  RD3094937631331884     43.52       673.43        44.17      717.60
#
#       payment_method
# 0         Amazon Pay
# 1              Paytm
# 2                NaN
# 3            QR scan
# 4         Amazon Pay
# ...              ...
# 49995     Amazon Pay
# 49996          Paytm
# 49997          Paytm
# 49998     Amazon Pay
# 49999     Amazon Pay
#
# [50000 rows x 13 columns]

# %%
df.head(20)
# Out:
#        services        date             time ride_status  \
# 0   cab economy  2024-07-15  08:30:40.542646   completed
# 1          auto  2024-07-05  23:36:51.542646   completed
# 2          auto  2024-07-23  11:05:37.542646   cancelled
# 3   cab economy  2024-06-24  08:45:10.542646   completed
# 4   cab economy  2024-07-15  00:26:44.542646   completed
# 5          auto  2024-07-02  01:28:29.542646   completed
# 6   cab economy  2024-07-23  20:55:28.542646   completed
# 7        parcel  2024-07-18  13:38:33.542646   completed
# 8        parcel  2024-08-08  07:59:53.542646   completed
# 9     bike lite  2024-07-10  12:30:07.542646   completed
# 10         auto  2024-08-03  16:57:14.542646   completed
# 11  cab economy  2024-07-08  17:46:15.542646   completed
# 12  cab economy  2024-08-10  13:46:07.542646   completed
# 13       parcel  2024-08-15  22:59:04.542646   cancelled
# 14         bike  2024-07-22  13:07:16.542646   cancelled
# 15         bike  2024-07-24  05:35:38.542646   completed
# 16         bike  2024-07-26  18:53:03.542646   completed
# 17         auto  2024-06-28  22:55:08.542646   completed
# 18         auto  2024-08-08  11:59:04.542646   completed
# 19       parcel  2024-08-08  00:57:02.542646   completed
#
#                      source                 destination  duration  \
# 0           Balagere Harbor             Harohalli Nagar        39
# 1    Basavanagudi 3rd Block        Bikasipura 1st Stage        89
# 2          Babusapalya Cove           Kothaguda Terrace        25
# 3         Mahadevapura Mews              Kanakapura Arc        89
# 4           Ganganagar Cove    Basaveshwaranagar Colony        95
# 5           HSR Layout Area          JP Nagar Viewpoint        18
# 6           Arekere Heights      Dooravani Nagar Pointe        85
# 7   Electronic City Village          Ganganagar Station        89
# 8          Mysore Road Lane      Billekahalli 6th Block        72
# 9        Kundalahalli Alley          RT Nagar 5th Block        94
# 10          Hosur Road Mews             Nagawara Layout        80
# 11         Bikasipura Close               Kadugodi Park        42
# 12       Mahadevapura Track              Whitefield Cut        68
# 13   Bhadrappa Layout Vista         Subramanyapura Road        82
# 14        Frazer Town Works  Hebbal Kempapura Viewpoint        44
# 15             Nagawara Dam          Dommasandra Colony        42
# 16      Sonnenahalli Layout               Kothanur Loop        95
# 17         Hulimavu Cutting          HRBR Layout Valley        37
# 18        Billekahalli Cove       Hennur Road 1st Block        42
# 19       Banaswadi District       Sadashiva Nagar Court        50
#
#                ride_id  distance  ride_charge  misc_charge  total_fare  \
# 0   RD3161218751875354     27.21       764.83        31.51      796.34
# 1   RD8171514284594096     34.03       314.83        49.52      364.35
# 2   RD9376481122237926     20.24          NaN          NaN         NaN
# 3   RD3676889143182765     31.17       484.73        15.84      500.57
# 4   RD6639410275948084     27.21       663.50        14.13      677.63
# 5   RD5922205486441934     33.69       456.73        25.19      481.92
# 6   RD9557099396888459     20.44       836.39        14.95      851.34
# 7   RD9473873953525644     35.31       724.76        31.34      756.10
# 8   RD1285566012167240     45.99       641.55        21.48      663.03
# 9   RD7238628094142076     44.43       571.50        47.63      619.13
# 10  RD0988431403518514      5.25       356.07        33.18      389.25
# 11  RD1746298517733148     18.53       920.85        44.03      964.88
# 12  RD7341504775683700      5.11       595.80        23.72      619.52
# 13  RD0256680118366791     29.83          NaN          NaN         NaN
# 14  RD7115059402806582     49.92          NaN          NaN         NaN
# 15  RD2369646812729540     39.30       256.39        31.98      288.37
# 16  RD8047989809002405     21.39        62.83        23.51       86.34
# 17  RD3592571330485165     48.12       811.27        41.32      852.59
# 18  RD8817673455871975      2.36       188.04        46.52      234.56
# 19  RD1385843052752492     37.50       473.87        13.24      487.11
#
#    payment_method
# 0      Amazon Pay
# 1           Paytm
# 2             NaN
# 3         QR scan
# 4      Amazon Pay
# 5         QR scan
# 6            GPay
# 7         QR scan
# 8      Amazon Pay
# 9         QR scan
# 10        QR scan
# 11          Paytm
# 12          Paytm
# 13            NaN
# 14            NaN
# 15          Paytm
# 16          Paytm
# 17     Amazon Pay
# 18           GPay
# 19     Amazon Pay

# %%
df.tail(20)
# Out:
#           services        date             time ride_status  \
# 49980         bike  2024-06-18  09:34:39.811393   completed
# 49981         bike  2024-07-29  06:04:45.811393   cancelled
# 49982         auto  2024-07-16  19:07:34.811393   completed
# 49983  cab economy  2024-07-06  17:17:25.811393   completed
# 49984         bike  2024-07-22  22:25:58.811393   completed
# 49985         bike  2024-07-28  09:57:00.811393   completed
# 49986         bike  2024-06-22  23:14:38.811393   completed
# 49987    bike lite  2024-07-04  10:02:46.811393   completed
# 49988       parcel  2024-06-29  05:41:48.811393   completed
# 49989  cab economy  2024-07-30  03:39:52.811393   completed
# 49990         auto  2024-06-30  21:46:46.811393   completed
# 49991       parcel  2024-06-25  06:00:11.811393   completed
# 49992         auto  2024-06-25  01:41:20.811393   completed
# 49993  cab economy  2024-07-24  23:02:45.811393   completed
# 49994         auto  2024-07-04  18:20:12.811393   completed
# 49995  cab economy  2024-07-24  10:12:37.811393   completed
# 49996         auto  2024-08-12  11:24:08.811393   completed
# 49997         bike  2024-08-10  21:52:48.811393   completed
# 49998         auto  2024-07-07  20:44:00.811393   completed
# 49999  cab economy  2024-08-07  08:53:25.811393   completed
#
#                                 source                 destination  duration  \
# 49980                    Hebbal Sector  Kumaraswamy Layout Passage        57
# 49981      Koramangala 4th Block Nagar         Bikasipura Township        41
# 49982                  Tavarekere Quay              Yelahanka Loop        88
# 49983             Marathahalli Meadows         Banaswadi 3rd Block        89
# 49984                 Madiwala Complex       Chikkalasandra Layout        37
# 49985              Benson Town Terrace      Vasanth Nagar District       110
# 49986                     Hulimavu Bay  Koramangala 7th Block Lane        67
# 49987         Lingarajapuram Esplanade      Malleshwaram 3rd Block        59
# 49988                   Gottigere View          Gottigere Quarters        55
# 49989                  Srirampura Yard             Kothnur Meadows        51
# 49990  Dr. Shivaram Karanth Nagar Side            Nagasandra Nagar        25
# 49991                JP Nagar Township           Nayandahalli Cove       109
# 49992               Kothanur 5th Block            Billekahalli Dam       110
# 49993               Anjanapura Meadows          Rachenahalli Farms        42
# 49994               BTM 2nd Stage Loop    Hebbal Kempapura Complex       114
# 49995              Giri Nagar Quarters      Lingarajapuram Village        79
# 49996             Hennur Road District               Hulimavu Pier        39
# 49997                    Agara Heights            Ulsoor 4th Block        40
# 49998                     Hosur Colony            Kanakapura Works       111
# 49999              BTM 2nd Stage Depot            Thanisandra Pass        28
#
#                   ride_id  distance  ride_charge  misc_charge  total_fare  \
# 49980  RD2697418539661618     41.99       804.90        32.45      837.35
# 49981  RD7890979691996507     36.73          NaN          NaN         NaN
# 49982  RD8032828087051925     44.27       973.59        39.79     1013.38
# 49983  RD3651553384597907     30.45       828.07        39.14      867.21
# 49984  RD1216619104405983     19.58       170.39        12.91      183.30
# 49985  RD0362015379935788     20.45       717.57         8.80      726.37
# 49986  RD2562271284650397      4.76       415.62        38.47      454.09
# 49987  RD3118577696286566     46.25       416.38         2.57      418.95
# 49988  RD0779077549639536     23.43       706.51        20.82      727.33
# 49989  RD6869500537012591      3.50       996.10         0.59      996.69
# 49990  RD5595517654534018     33.77       723.54        38.92      762.46
# 49991  RD5786299057241505     38.39       547.85         7.17      555.02
# 49992  RD4774725082873987     26.66       952.36        39.98      992.34
# 49993  RD0145980682360373      5.28       778.16        13.68      791.84
# 49994  RD5704073223802164      8.03       329.12        34.47      363.59
# 49995  RD1742789687725650      7.03       518.90        23.81      542.71
# 49996  RD3524793949448023     31.77       977.34         2.67      980.01
# 49997  RD6755775741450371     25.74       331.94        38.32      370.26
# 49998  RD9198658614373790     11.70       565.47         0.33      565.80
# 49999  RD3094937631331884     43.52       673.43        44.17      717.60
#
#       payment_method
# 49980        QR scan
# 49981            NaN
# 49982        QR scan
# 49983           GPay
# 49984           GPay
# 49985        QR scan
# 49986     Amazon Pay
# 49987        QR scan
# 49988          Paytm
# 49989        QR scan
# 49990     Amazon Pay
# 49991        QR scan
# 49992           GPay
# 49993        QR scan
# 49994           GPay
# 49995     Amazon Pay
# 49996          Paytm
# 49997          Paytm
# 49998     Amazon Pay
# 49999     Amazon Pay

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   services        50000 non-null  object
#  1   date            50000 non-null  object
#  2   time            50000 non-null  object
#  3   ride_status     50000 non-null  object
#  4   source          50000 non-null  object
#  5   destination     50000 non-null  object
#  6   duration        50000 non-null  int64
#  7   ride_id         50000 non-null  object
#  8   distance        50000 non-null  float64
#  9   ride_charge     44964 non-null  float64
#  10  misc_charge     44964 non-null  float64
#  11  total_fare      44964 non-null  float64
#  12  payment_method  44964 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 5.0+ MB

# %% [markdown]
# CLEANING

# %%
df.isna().sum()
# Out:
# services             0
# date                 0
# time                 0
# ride_status          0
# source               0
# destination          0
# duration             0
# ride_id              0
# distance             0
# ride_charge       5036
# misc_charge       5036
# total_fare        5036
# payment_method    5036
# dtype: int64

# %%
df[df['ride_status']=='cancelled']
# Out:
#           services        date             time ride_status  \
# 2             auto  2024-07-23  11:05:37.542646   cancelled
# 13          parcel  2024-08-15  22:59:04.542646   cancelled
# 14            bike  2024-07-22  13:07:16.542646   cancelled
# 29     cab economy  2024-07-20  12:24:50.542646   cancelled
# 31            auto  2024-07-06  11:05:31.542646   cancelled
# ...            ...         ...              ...         ...
# 49939         auto  2024-07-23  21:03:44.811393   cancelled
# 49944    bike lite  2024-08-09  07:10:52.811393   cancelled
# 49949       parcel  2024-08-02  10:25:45.811393   cancelled
# 49974  cab economy  2024-08-03  17:54:14.811393   cancelled
# 49981         bike  2024-07-29  06:04:45.811393   cancelled
#
#                             source                       destination  \
# 2                 Babusapalya Cove                 Kothaguda Terrace
# 13          Bhadrappa Layout Vista               Subramanyapura Road
# 14               Frazer Town Works        Hebbal Kempapura Viewpoint
# 29           Vidyaranyapura Summit                        Agara Mews
# 31             Chikkagubbi Village         Horamavu Banaswadi Alcove
# ...                            ...                               ...
# 49939           Nagasandra Heights        Devarachikkanahalli Quarry
# 49944          Horamavu Agara Side               Doddaballapur Hills
# 49949        Vijayanagar 6th Stage  Hosur Sarjapur Road Layout Hills
# 49974           Kanaka Nagar Track                  Hennur Road Road
# 49981  Koramangala 4th Block Nagar               Bikasipura Township
#
#        duration             ride_id  distance  ride_charge  misc_charge  \
# 2            25  RD9376481122237926     20.24          NaN          NaN
# 13           82  RD0256680118366791     29.83          NaN          NaN
# 14           44  RD7115059402806582     49.92          NaN          NaN
# 29           48  RD8925634951822521      7.05          NaN          NaN
# 31          118  RD7321545592072979      9.25          NaN          NaN
# ...         ...                 ...       ...          ...          ...
# 49939        22  RD2354294886972474     27.57          NaN          NaN
# 49944       112  RD8113947470306971     30.26          NaN          NaN
# 49949        71  RD3966769615370909     21.42          NaN          NaN
# 49974        67  RD8550176162165676     22.01          NaN          NaN
# 49981        41  RD7890979691996507     36.73          NaN          NaN
#
#        total_fare payment_method
# 2             NaN            NaN
# 13            NaN            NaN
# 14            NaN            NaN
# 29            NaN            NaN
# 31            NaN            NaN
# ...           ...            ...
# 49939         NaN            NaN
# 49944         NaN            NaN
# 49949         NaN            NaN
# 49974         NaN            NaN
# 49981         NaN            NaN
#
# [5036 rows x 13 columns]

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# services             0
# date                 0
# time                 0
# ride_status          0
# source               0
# destination          0
# duration             0
# ride_id              0
# distance             0
# ride_charge       5036
# misc_charge       5036
# total_fare        5036
# payment_method    5036
# dtype: int64

# %%
# Filling null values for canceled rides
df.loc[df['ride_status'] == 'cancelled', ['ride_charge', 'misc_charge', 'total_fare']] = 0
df.loc[df['ride_status'] == 'cancelled', 'payment_method'] = 'cancelled'

# %%
df.loc[df['ride_status'] == 'cancelled',['services']]
# Out:
#           services
# 2             auto
# 13          parcel
# 14            bike
# 29     cab economy
# 31            auto
# ...            ...
# 49939         auto
# 49944    bike lite
# 49949       parcel
# 49974  cab economy
# 49981         bike
#
# [5036 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# services          0
# date              0
# time              0
# ride_status       0
# source            0
# destination       0
# duration          0
# ride_id           0
# distance          0
# ride_charge       0
# misc_charge       0
# total_fare        0
# payment_method    0
# dtype: int64

# %%
df.head(30)
# Out:
#        services        date             time ride_status  \
# 0   cab economy  2024-07-15  08:30:40.542646   completed
# 1          auto  2024-07-05  23:36:51.542646   completed
# 2          auto  2024-07-23  11:05:37.542646   cancelled
# 3   cab economy  2024-06-24  08:45:10.542646   completed
# 4   cab economy  2024-07-15  00:26:44.542646   completed
# 5          auto  2024-07-02  01:28:29.542646   completed
# 6   cab economy  2024-07-23  20:55:28.542646   completed
# 7        parcel  2024-07-18  13:38:33.542646   completed
# 8        parcel  2024-08-08  07:59:53.542646   completed
# 9     bike lite  2024-07-10  12:30:07.542646   completed
# 10         auto  2024-08-03  16:57:14.542646   completed
# 11  cab economy  2024-07-08  17:46:15.542646   completed
# 12  cab economy  2024-08-10  13:46:07.542646   completed
# 13       parcel  2024-08-15  22:59:04.542646   cancelled
# 14         bike  2024-07-22  13:07:16.542646   cancelled
# 15         bike  2024-07-24  05:35:38.542646   completed
# 16         bike  2024-07-26  18:53:03.542646   completed
# 17         auto  2024-06-28  22:55:08.542646   completed
# 18         auto  2024-08-08  11:59:04.542646   completed
# 19       parcel  2024-08-08  00:57:02.542646   completed
# 20       parcel  2024-07-22  10:04:38.542646   completed
# 21         auto  2024-07-03  01:01:29.542646   completed
# 22  cab economy  2024-07-08  01:16:16.542646   completed
# 23         auto  2024-07-01  07:18:36.542646   completed
# 24         bike  2024-06-21  06:23:04.542646   completed
# 25         auto  2024-08-03  08:46:32.542646   completed
# 26         bike  2024-06-29  01:00:58.542646   completed
# 27       parcel  2024-07-02  04:10:03.542646   completed
# 28  cab economy  2024-06-28  01:18:09.542646   completed
# 29  cab economy  2024-07-20  12:24:50.542646   cancelled
#
#                          source                  destination  duration  \
# 0               Balagere Harbor              Harohalli Nagar        39
# 1        Basavanagudi 3rd Block         Bikasipura 1st Stage        89
# 2              Babusapalya Cove            Kothaguda Terrace        25
# 3             Mahadevapura Mews               Kanakapura Arc        89
# 4               Ganganagar Cove     Basaveshwaranagar Colony        95
# 5               HSR Layout Area           JP Nagar Viewpoint        18
# 6               Arekere Heights       Dooravani Nagar Pointe        85
# 7       Electronic City Village           Ganganagar Station        89
# 8              Mysore Road Lane       Billekahalli 6th Block        72
# 9            Kundalahalli Alley           RT Nagar 5th Block        94
# 10              Hosur Road Mews              Nagawara Layout        80
# 11             Bikasipura Close                Kadugodi Park        42
# 12           Mahadevapura Track               Whitefield Cut        68
# 13       Bhadrappa Layout Vista          Subramanyapura Road        82
# 14            Frazer Town Works   Hebbal Kempapura Viewpoint        44
# 15                 Nagawara Dam           Dommasandra Colony        42
# 16          Sonnenahalli Layout                Kothanur Loop        95
# 17             Hulimavu Cutting           HRBR Layout Valley        37
# 18            Billekahalli Cove        Hennur Road 1st Block        42
# 19           Banaswadi District        Sadashiva Nagar Court        50
# 20       Hebbal Kempapura Ridge           Ramnagar 1st Stage       104
# 21  Rajarajeshwari Nagar Bridge             ITI Layout Close        11
# 22            Kudlu Gate Fields          Subramanyapura Pass       117
# 23        Byatarayanapura Plaza  Koramangala 6th Block Ridge        46
# 24             Whitefield Hills                MG Road Hills        49
# 25  Koramangala 4th Block Place          Jakkasandra Landing        95
# 26           Balagere 1st Stage            Sonnenahalli Lane       105
# 27              Kothaguda Vista                 Bagalur Lane        71
# 28               Jakkur Meadows    Rajarajeshwari Nagar Pass        47
# 29        Vidyaranyapura Summit                   Agara Mews        48
#
#                ride_id  distance  ride_charge  misc_charge  total_fare  \
# 0   RD3161218751875354     27.21       764.83        31.51      796.34
# 1   RD8171514284594096     34.03       314.83        49.52      364.35
# 2   RD9376481122237926     20.24         0.00         0.00        0.00
# 3   RD3676889143182765     31.17       484.73        15.84      500.57
# 4   RD6639410275948084     27.21       663.50        14.13      677.63
# 5   RD5922205486441934     33.69       456.73        25.19      481.92
# 6   RD9557099396888459     20.44       836.39        14.95      851.34
# 7   RD9473873953525644     35.31       724.76        31.34      756.10
# 8   RD1285566012167240     45.99       641.55        21.48      663.03
# 9   RD7238628094142076     44.43       571.50        47.63      619.13
# 10  RD0988431403518514      5.25       356.07        33.18      389.25
# 11  RD1746298517733148     18.53       920.85        44.03      964.88
# 12  RD7341504775683700      5.11       595.80        23.72      619.52
# 13  RD0256680118366791     29.83         0.00         0.00        0.00
# 14  RD7115059402806582     49.92         0.00         0.00        0.00
# 15  RD2369646812729540     39.30       256.39        31.98      288.37
# 16  RD8047989809002405     21.39        62.83        23.51       86.34
# 17  RD3592571330485165     48.12       811.27        41.32      852.59
# 18  RD8817673455871975      2.36       188.04        46.52      234.56
# 19  RD1385843052752492     37.50       473.87        13.24      487.11
# 20  RD7208906531384606      3.04       617.35        33.34      650.69
# 21  RD0654632158879742      9.52       306.79        44.68      351.47
# 22  RD2239177732142431     37.93       853.42        39.57      892.99
# 23  RD1117035760652729     21.60       907.37        20.55      927.92
# 24  RD4226811079858075     12.80       131.29        29.98      161.27
# 25  RD1382587140891268     21.43        70.55        45.91      116.46
# 26  RD4382177005818484     29.09       221.09        27.50      248.59
# 27  RD7958326265710860      5.94       707.21         1.91      709.12
# 28  RD1055432783395596     28.64       484.33        34.22      518.55
# 29  RD8925634951822521      7.05         0.00         0.00        0.00
#
#    payment_method
# 0      Amazon Pay
# 1           Paytm
# 2       cancelled
# 3         QR scan
# 4      Amazon Pay
# 5         QR scan
# 6            GPay
# 7         QR scan
# 8      Amazon Pay
# 9         QR scan
# 10        QR scan
# 11          Paytm
# 12          Paytm
# 13      cancelled
# 14      cancelled
# 15          Paytm
# 16          Paytm
# 17     Amazon Pay
# 18           GPay
# 19     Amazon Pay
# 20          Paytm
# 21           GPay
# 22           GPay
# 23           GPay
# 24           GPay
# 25           GPay
# 26        QR scan
# 27          Paytm
# 28          Paytm
# 29      cancelled

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# services           object
# date               object
# time               object
# ride_status        object
# source             object
# destination        object
# duration            int64
# ride_id            object
# distance          float64
# ride_charge       float64
# misc_charge       float64
# total_fare        float64
# payment_method     object
# dtype: object

# %% [markdown]
# Feature engineering

# %%
def cate(i):
  if i['ride_status']=='cancelled':
    return 'Cancelled'
  elif i['distance']<5:
    return 'Short'
  elif i['distance']>=5 and  i['distance']<=15:
    return 'Medium'
  else:
    return 'Long'

# %%
df['distance_category'] = df.apply(cate, axis=1)

# %%
df.head(5)
# Out:
#       services        date             time ride_status  \
# 0  cab economy  2024-07-15  08:30:40.542646   completed
# 1         auto  2024-07-05  23:36:51.542646   completed
# 2         auto  2024-07-23  11:05:37.542646   cancelled
# 3  cab economy  2024-06-24  08:45:10.542646   completed
# 4  cab economy  2024-07-15  00:26:44.542646   completed
#
#                    source               destination  duration  \
# 0         Balagere Harbor           Harohalli Nagar        39
# 1  Basavanagudi 3rd Block      Bikasipura 1st Stage        89
# 2        Babusapalya Cove         Kothaguda Terrace        25
# 3       Mahadevapura Mews            Kanakapura Arc        89
# 4         Ganganagar Cove  Basaveshwaranagar Colony        95
#
#               ride_id  distance  ride_charge  misc_charge  total_fare  \
# 0  RD3161218751875354     27.21       764.83        31.51      796.34
# 1  RD8171514284594096     34.03       314.83        49.52      364.35
# 2  RD9376481122237926     20.24         0.00         0.00        0.00
# 3  RD3676889143182765     31.17       484.73        15.84      500.57
# 4  RD6639410275948084     27.21       663.50        14.13      677.63
#
#   payment_method distance_category
# 0     Amazon Pay              Long
# 1          Paytm              Long
# 2      cancelled         Cancelled
# 3        QR scan              Long
# 4     Amazon Pay              Long

# %% [markdown]
# ANALYSIS

# %%
df.describe()
# Out:
#            duration      distance   ride_charge   misc_charge    total_fare
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean      64.320100     25.528243    469.809776     22.449885    492.259661
# std       31.852336     14.177136    304.292438     15.635392    308.537369
# min       10.000000      1.000000      0.000000      0.000000      0.000000
# 25%       37.000000     13.260000    205.207500      8.190000    229.360000
# 50%       64.000000     25.460000    466.770000     22.210000    491.350000
# 75%       92.000000     37.860000    733.267500     36.060000    758.415000
# max      119.000000     50.000000    999.960000     50.000000   1048.800000

# %%
df[df['total_fare']==1048.800000] # parcel
# Out:
#      services        date             time ride_status              source  \
# 2904   parcel  2024-06-20  10:19:30.557662   completed  Thanisandra Summit
#
#                 destination  duration             ride_id  distance  \
# 2904  Jakkasandra 4th Stage        58  RD7417292312338710      4.49
#
#       ride_charge  misc_charge  total_fare payment_method distance_category
# 2904       999.75        49.05      1048.8          Paytm             Short

# %%
df['ride_charge'].sum()
# Out:
# 23490488.779999997

# %%
df['misc_charge'].sum()
# Out:
# 1122494.2700000003

# %% [markdown]
# outlier detection

# %%
obj=[]
num=[]
for i in df:
  if df[i].dtype == 'object':
    obj.append(i)
  else:
    num.append(i)

# %%
obj
# Out:
# ['services',
#  'date',
#  'time',
#  'ride_status',
#  'source',
#  'destination',
#  'ride_id',
#  'payment_method',
#  'distance_category']

# %%
num
# Out:
# ['duration', 'distance', 'ride_charge', 'misc_charge', 'total_fare']

# %%
import matplotlib.pyplot as plt
for i in num:
    plt.figure(figsize=(7,6))
    plt.boxplot(df[i])
    plt.title(f"Box Plot of {i}")
    plt.show()

# %%
#UNIVARIATE ANALYSIS:

# %%
for col in num:
  print(col)
  print('------------------------')
  print(f'Mean : {df[col].mean()}')
  print(f'Median : {df[col].median()}')
  print(f'Minimum of {col} : {df[col].min()}')
  print(f'Maximum of {col} : {df[col].max()}')
  print(f'Standard Deviation : {df[col].std()}')
  print(f'Variance : {df[col].var()}')
  print('********************************************')
  print()
# Out:
# duration
# ------------------------
# Mean : 64.3201
# Median : 64.0
# Minimum of duration : 10
# Maximum of duration : 119
# Standard Deviation : 31.852335666568685
# Variance : 1014.5712874157634
# ********************************************
#
# distance
# ------------------------
# Mean : 25.5282432
# Median : 25.46
# Minimum of distance : 1.0
# Maximum of distance : 50.0
# Standard Deviation : 14.177136033535787
# Variance : 200.9911861133788
# ********************************************
#
# ride_charge
# ------------------------
# Mean : 469.80977559999997
# Median : 466.77
# Minimum of ride_charge : 0.0
# Maximum of ride_charge : 999.96
# Standard Deviation : 304.2924380916173
# Variance : 92593.88787974077
# ********************************************
#
# misc_charge
# ------------------------
# Mean : 22.449885400000007
# Median : 22.21
# Minimum of misc_charge : 0.0
# Maximum of misc_charge : 50.0
# Standard Deviation : 15.63539232071728
# Variance : 244.4654930227449
# ********************************************
#
# total_fare
# ------------------------
# Mean : 492.25966099999994
# Median : 491.35
# Minimum of total_fare : 0.0
# Maximum of total_fare : 1048.8
# Standard Deviation : 308.5373692982152
# Variance : 95195.30825346321
# ********************************************

# %%
# to draw hist plot of numerical columns graphically using for loop
for col in df:
  if df[col].dtype=="int" or df[col].dtype=='float':
    plt.figure(figsize=(6,4))   # figsize(width,height)
    plt.hist(df[col],bins=15)
    plt.title(f"Histplot of {col}")
    plt.yscale('log')
    plt.xlabel(f"{col}")
    plt.ylabel('Count')
    plt.show()

# %%
#Calculate the percentage of canceled rides versus completed rides for an overview of ride success.

# %%
ride_status_counts = df.groupby('ride_status').size()
ride_status_counts

ride_status_percentages = (ride_status_counts / len(df)) * 100 # returns a series

# percentages for canceled and completed rides
canceled_percentage = ride_status_percentages.get('cancelled', 0)# key and default
completed_percentage = ride_status_percentages.get('completed', 0)


print(f"Percentage of Canceled Rides: {canceled_percentage:.2f}%")
print(f"Percentage of Completed Rides: {completed_percentage:.2f}%")
# Out:
# Percentage of Canceled Rides: 10.07%
# Percentage of Completed Rides: 89.93%

# %%
ride_status_percentages = (ride_status_counts / len(df)) * 100
ride_status_percentages
# Out:
# ride_status
# cancelled    10.072
# completed    89.928
# dtype: float64

# %%
# j=df['source'].value_counts().get('Balagere Harbor',0)
# j

# %%
#PIE PLOT OF SERVIECES

# %%
plt.pie(df['services'].value_counts(),labels=df['services'].value_counts().index,autopct="%1.0f%%")
plt.show()

# %%
plt.pie(df['payment_method'].value_counts(),labels=df['payment_method'].value_counts().index,autopct="%1.0f%%")
plt.show()

# %%
df['payment_method'].value_counts()
# Out:
# payment_method
# Paytm         11315
# GPay          11268
# Amazon Pay    11225
# QR scan       11156
# cancelled      5036
# Name: count, dtype: int64

# %%
#hist plot of numerical colunms:
for col in df:
  if df[col].dtype=="int" or df[col].dtype=='float':
    plt.figure(figsize=(6,4))   # figsize(width,height)
    plt.hist(df[col],bins=10)
    plt.title(f"Histplot of {col}")
    plt.yscale('log') # chnaging to log scale for more visible clarity
    plt.xlabel(f"{col}")
    plt.ylabel('Count')
    plt.show()

# %%
for col in df:
  if df[col].dtype=="int" or df[col].dtype=='float':
    plt.figure(figsize=(6,4))   # figsize(width,height)
    plt.hist(df[col],bins=10)
    plt.title(f"Histplot of {col}")
    plt.xlabel(f"{col}")
    plt.ylabel('Count')
    plt.show()

# %%
# which hour is the most prefered:

# %%
df['time'] = pd.to_datetime(df['time'], format='%H:%M:%S.%f')
df['hour'] = df['time'].dt.hour
df
# Out:
#           services        date                       time ride_status  \
# 0      cab economy  2024-07-15 1900-01-01 08:30:40.542646   completed
# 1             auto  2024-07-05 1900-01-01 23:36:51.542646   completed
# 2             auto  2024-07-23 1900-01-01 11:05:37.542646   cancelled
# 3      cab economy  2024-06-24 1900-01-01 08:45:10.542646   completed
# 4      cab economy  2024-07-15 1900-01-01 00:26:44.542646   completed
# ...            ...         ...                        ...         ...
# 49995  cab economy  2024-07-24 1900-01-01 10:12:37.811393   completed
# 49996         auto  2024-08-12 1900-01-01 11:24:08.811393   completed
# 49997         bike  2024-08-10 1900-01-01 21:52:48.811393   completed
# 49998         auto  2024-07-07 1900-01-01 20:44:00.811393   completed
# 49999  cab economy  2024-08-07 1900-01-01 08:53:25.811393   completed
#
#                        source               destination  duration  \
# 0             Balagere Harbor           Harohalli Nagar        39
# 1      Basavanagudi 3rd Block      Bikasipura 1st Stage        89
# 2            Babusapalya Cove         Kothaguda Terrace        25
# 3           Mahadevapura Mews            Kanakapura Arc        89
# 4             Ganganagar Cove  Basaveshwaranagar Colony        95
# ...                       ...                       ...       ...
# 49995     Giri Nagar Quarters    Lingarajapuram Village        79
# 49996    Hennur Road District             Hulimavu Pier        39
# 49997           Agara Heights          Ulsoor 4th Block        40
# 49998            Hosur Colony          Kanakapura Works       111
# 49999     BTM 2nd Stage Depot          Thanisandra Pass        28
#
#                   ride_id  distance  ride_charge  misc_charge  total_fare  \
# 0      RD3161218751875354     27.21       764.83        31.51      796.34
# 1      RD8171514284594096     34.03       314.83        49.52      364.35
# 2      RD9376481122237926     20.24         0.00         0.00        0.00
# 3      RD3676889143182765     31.17       484.73        15.84      500.57
# 4      RD6639410275948084     27.21       663.50        14.13      677.63
# ...                   ...       ...          ...          ...         ...
# 49995  RD1742789687725650      7.03       518.90        23.81      542.71
# 49996  RD3524793949448023     31.77       977.34         2.67      980.01
# 49997  RD6755775741450371     25.74       331.94        38.32      370.26
# 49998  RD9198658614373790     11.70       565.47         0.33      565.80
# 49999  RD3094937631331884     43.52       673.43        44.17      717.60
#
#       payment_method distance_category  hour
# 0         Amazon Pay              Long     8
# 1              Paytm              Long    23
# 2          cancelled         Cancelled    11
# 3            QR scan              Long     8
# 4         Amazon Pay              Long     0
# ...              ...               ...   ...
# 49995     Amazon Pay            Medium    10
# 49996          Paytm              Long    11
# 49997          Paytm              Long    21
# 49998     Amazon Pay            Medium    20
# 49999     Amazon Pay              Long     8
#
# [50000 rows x 15 columns]

# %%
import seaborn as sns
sns.countplot(x=df['hour'])
plt.xticks(rotation=45)
plt.yscale('log')
plt.show()

# %%
df['hour'].value_counts()
# Out:
# hour
# 9     2185
# 11    2181
# 10    2114
# 7     2112
# 13    2111
# 8     2106
# 1     2105
# 5     2103
# 22    2096
# 17    2095
# 18    2094
# 19    2086
# 21    2083
# 4     2082
# 15    2082
# 20    2073
# 6     2073
# 12    2070
# 3     2066
# 0     2037
# 16    2026
# 14    2017
# 23    2003
# 2     2000
# Name: count, dtype: int64

# %%
# to find which day is most prefered:

# %%
df['date'] = pd.to_datetime(df['date'])
df['day_name'] = df['date'].dt.day_name()

# %%
df
# Out:
#           services       date                       time ride_status  \
# 0      cab economy 2024-07-15 1900-01-01 08:30:40.542646   completed
# 1             auto 2024-07-05 1900-01-01 23:36:51.542646   completed
# 2             auto 2024-07-23 1900-01-01 11:05:37.542646   cancelled
# 3      cab economy 2024-06-24 1900-01-01 08:45:10.542646   completed
# 4      cab economy 2024-07-15 1900-01-01 00:26:44.542646   completed
# ...            ...        ...                        ...         ...
# 49995  cab economy 2024-07-24 1900-01-01 10:12:37.811393   completed
# 49996         auto 2024-08-12 1900-01-01 11:24:08.811393   completed
# 49997         bike 2024-08-10 1900-01-01 21:52:48.811393   completed
# 49998         auto 2024-07-07 1900-01-01 20:44:00.811393   completed
# 49999  cab economy 2024-08-07 1900-01-01 08:53:25.811393   completed
#
#                        source               destination  duration  \
# 0             Balagere Harbor           Harohalli Nagar        39
# 1      Basavanagudi 3rd Block      Bikasipura 1st Stage        89
# 2            Babusapalya Cove         Kothaguda Terrace        25
# 3           Mahadevapura Mews            Kanakapura Arc        89
# 4             Ganganagar Cove  Basaveshwaranagar Colony        95
# ...                       ...                       ...       ...
# 49995     Giri Nagar Quarters    Lingarajapuram Village        79
# 49996    Hennur Road District             Hulimavu Pier        39
# 49997           Agara Heights          Ulsoor 4th Block        40
# 49998            Hosur Colony          Kanakapura Works       111
# 49999     BTM 2nd Stage Depot          Thanisandra Pass        28
#
#                   ride_id  distance  ride_charge  misc_charge  total_fare  \
# 0      RD3161218751875354     27.21       764.83        31.51      796.34
# 1      RD8171514284594096     34.03       314.83        49.52      364.35
# 2      RD9376481122237926     20.24         0.00         0.00        0.00
# 3      RD3676889143182765     31.17       484.73        15.84      500.57
# 4      RD6639410275948084     27.21       663.50        14.13      677.63
# ...                   ...       ...          ...          ...         ...
# 49995  RD1742789687725650      7.03       518.90        23.81      542.71
# 49996  RD3524793949448023     31.77       977.34         2.67      980.01
# 49997  RD6755775741450371     25.74       331.94        38.32      370.26
# 49998  RD9198658614373790     11.70       565.47         0.33      565.80
# 49999  RD3094937631331884     43.52       673.43        44.17      717.60
#
#       payment_method distance_category  hour   day_name
# 0         Amazon Pay              Long     8     Monday
# 1              Paytm              Long    23     Friday
# 2          cancelled         Cancelled    11    Tuesday
# 3            QR scan              Long     8     Monday
# 4         Amazon Pay              Long     0     Monday
# ...              ...               ...   ...        ...
# 49995     Amazon Pay            Medium    10  Wednesday
# 49996          Paytm              Long    11     Monday
# 49997          Paytm              Long    21   Saturday
# 49998     Amazon Pay            Medium    20     Sunday
# 49999     Amazon Pay              Long     8  Wednesday
#
# [50000 rows x 16 columns]

# %%
day_counts = df['day_name'].groupby(df['day_name']).count()

# %%
day_counts.sort_values(ascending=True)
# Out:
# day_name
# Sunday       6540
# Saturday     6584
# Wednesday    7327
# Friday       7329
# Tuesday      7384
# Thursday     7404
# Monday       7432
# Name: day_name, dtype: int64

# %%
#visualization
plt.bar(x=day_counts.index,height=day_counts)
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(x=day_counts.index,height=day_counts)
plt.xticks(rotation=90)
plt.yscale('log')
plt.show()

# %%
#Find the most common pickup and drop-off locations by counting occurrences of source and destination.

# %%
source_count = df['source'].groupby(df['source']).count()
source_count.sort_values(ascending=False).head(10)
# Out:
# source
# Kothanur Landing            23
# Banaswadi Landing           20
# Vijayanagar Square          20
# HRBR Layout Landing         19
# Ramamurthy Nagar Landing    18
# Banaswadi Square            17
# HRBR Layout Square          16
# Kalyan Nagar Close          15
# Chokkanahalli Landing       15
# Kothanur 6th Block          15
# Name: source, dtype: int64

# %%
source_count = df['destination'].groupby(df['destination']).count()
source_count.sort_values(ascending=False).head(10)
# Out:
# destination
# Gottigere Landing             23
# Gottigere Square              20
# Kudlu Square                  17
# HRBR Layout Drive             17
# Harohalli Landing             16
# Gottigere 6th Block           16
# Hulimavu Drive                16
# Hulimavu Square               15
# Ramamurthy Nagar 6th Block    15
# Gottigere District            15
# Name: destination, dtype: int64

# %%
#  servies vs total fare

# %%
df[['services','total_fare']].groupby('services').agg(['count','mean','median','min','max','std'])
# Out:
#             total_fare
#                  count        mean   median  min      max         std
# services
# auto             12327  494.826910  498.560  0.0  1047.77  309.344324
# bike             15128  491.326279  489.355  0.0  1047.80  309.522042
# bike lite         4884  488.886280  486.140  0.0  1048.73  306.882732
# cab economy      10202  490.710943  489.390  0.0  1044.48  308.132447
# parcel            7459  494.237049  491.670  0.0  1048.80  306.869472

# %%
df[['services','duration']].groupby('services').agg(['count','mean','median','min','max','std'])
# Out:
#             duration
#                count       mean median min  max        std
# services
# auto           12327  64.916849   65.0  10  119  31.644540
# bike           15128  63.925172   63.0  10  119  31.736420
# bike lite       4884  64.117936   64.0  10  119  31.804048
# cab economy    10202  64.247893   64.0  10  119  32.245915
# parcel          7459  64.366001   64.0  10  119  31.912972

# %%
df[['services','distance']].groupby('services').agg(['count','mean','median','min','max','std'])
# Out:
#             distance
#                count       mean median   min    max        std
# services
# auto           12327  25.595676  25.54  1.00  49.99  14.165858
# bike           15128  25.385639  25.29  1.00  50.00  14.135848
# bike lite       4884  25.700749  25.58  1.00  49.99  14.132672
# cab economy    10202  25.497436  25.36  1.01  50.00  14.225781
# parcel          7459  25.635208  25.83  1.02  49.99  14.242602

# %%
#total revenue in payment method

# %%
df[['payment_method','total_fare']].groupby('payment_method').agg(['sum','count','mean','median','min','max']).sort_values(by=('total_fare', 'count'), ascending=True)
# Out:
#                 total_fare
#                        sum  count        mean   median    min      max
# payment_method
# cancelled             0.00   5036    0.000000    0.000   0.00     0.00
# QR scan         6109164.37  11156  547.612439  542.785  50.58  1048.50
# Amazon Pay      6131641.87  11225  546.248719  542.860  54.07  1048.34
# GPay            6171005.26  11268  547.657549  549.045  51.71  1048.73
# Paytm           6201171.55  11315  548.048745  544.180  54.87  1048.80

# %%
#total revenue in distance category

# %%
df[['distance_category','total_fare']].groupby('distance_category').agg(['sum','count','mean','median','min','max']).sort_values(by=('total_fare', 'count'), ascending=False)
# Out:
#                     total_fare
#                            sum  count        mean   median    min      max
# distance_category
# Long               17559047.23  32121  546.653194  543.530  51.08  1048.50
# Medium              5064196.18   9205  550.157108  548.620  55.32  1043.31
# Cancelled                 0.00   5036    0.000000    0.000   0.00     0.00
# Short               1989739.64   3638  546.932281  545.495  50.58  1048.80

# %%
# Heatmap (correlation matrix):
var1=df.corr(numeric_only=True)
sns.heatmap(var1,annot=True)
plt.title('Heatmap')
plt.show()

# %%
#plots the mean of total_fare for each services
var2=df[['services','total_fare']].groupby('services').mean()
plt.plot(var2.index,var2)
plt.title('Services Vs total fare')
plt.xlabel('service')
plt.ylabel('mean of total fare')
plt.show()

# %%
df
# Out:
#           services       date                       time ride_status  \
# 0      cab economy 2024-07-15 1900-01-01 08:30:40.542646   completed
# 1             auto 2024-07-05 1900-01-01 23:36:51.542646   completed
# 2             auto 2024-07-23 1900-01-01 11:05:37.542646   cancelled
# 3      cab economy 2024-06-24 1900-01-01 08:45:10.542646   completed
# 4      cab economy 2024-07-15 1900-01-01 00:26:44.542646   completed
# ...            ...        ...                        ...         ...
# 49995  cab economy 2024-07-24 1900-01-01 10:12:37.811393   completed
# 49996         auto 2024-08-12 1900-01-01 11:24:08.811393   completed
# 49997         bike 2024-08-10 1900-01-01 21:52:48.811393   completed
# 49998         auto 2024-07-07 1900-01-01 20:44:00.811393   completed
# 49999  cab economy 2024-08-07 1900-01-01 08:53:25.811393   completed
#
#                        source               destination  duration  \
# 0             Balagere Harbor           Harohalli Nagar        39
# 1      Basavanagudi 3rd Block      Bikasipura 1st Stage        89
# 2            Babusapalya Cove         Kothaguda Terrace        25
# 3           Mahadevapura Mews            Kanakapura Arc        89
# 4             Ganganagar Cove  Basaveshwaranagar Colony        95
# ...                       ...                       ...       ...
# 49995     Giri Nagar Quarters    Lingarajapuram Village        79
# 49996    Hennur Road District             Hulimavu Pier        39
# 49997           Agara Heights          Ulsoor 4th Block        40
# 49998            Hosur Colony          Kanakapura Works       111
# 49999     BTM 2nd Stage Depot          Thanisandra Pass        28
#
#                   ride_id  distance  ride_charge  misc_charge  total_fare  \
# 0      RD3161218751875354     27.21       764.83        31.51      796.34
# 1      RD8171514284594096     34.03       314.83        49.52      364.35
# 2      RD9376481122237926     20.24         0.00         0.00        0.00
# 3      RD3676889143182765     31.17       484.73        15.84      500.57
# 4      RD6639410275948084     27.21       663.50        14.13      677.63
# ...                   ...       ...          ...          ...         ...
# 49995  RD1742789687725650      7.03       518.90        23.81      542.71
# 49996  RD3524793949448023     31.77       977.34         2.67      980.01
# 49997  RD6755775741450371     25.74       331.94        38.32      370.26
# 49998  RD9198658614373790     11.70       565.47         0.33      565.80
# 49999  RD3094937631331884     43.52       673.43        44.17      717.60
#
#       payment_method distance_category  hour   day_name
# 0         Amazon Pay              Long     8     Monday
# 1              Paytm              Long    23     Friday
# 2          cancelled         Cancelled    11    Tuesday
# 3            QR scan              Long     8     Monday
# 4         Amazon Pay              Long     0     Monday
# ...              ...               ...   ...        ...
# 49995     Amazon Pay            Medium    10  Wednesday
# 49996          Paytm              Long    11     Monday
# 49997          Paytm              Long    21   Saturday
# 49998     Amazon Pay            Medium    20     Sunday
# 49999     Amazon Pay              Long     8  Wednesday
#
# [50000 rows x 16 columns]
